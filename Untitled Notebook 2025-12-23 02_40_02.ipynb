# %%
# %sh
# Search for your project folder name starting from the root
find /Workspace -name "azure-databricks-retail-lakehouse" -type d 2>/dev/null

# %%
# %sh
# 1. Navigate to the REAL folder location you just found
cd "/Workspace/Users/tithirbakshi@outlook.com/azure-databricks-retail-lakehouse"

# 2. Force the push to GitHub
git push -f origin main

# %%
# %sql
SELECT * FROM azure_databricks_personal.default.iot_telemetry_realtime 
ORDER BY timestamp DESC 
LIMIT 10
